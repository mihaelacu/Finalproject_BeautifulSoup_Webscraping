# %%
from selenium import webdriver
import requests
import pandas as pd
import seaborn as sns
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import numpy as np 
import pandas as pd 
import os
from pandas import read_csv
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("stanovi_analiza.csv")
data.head(10)
# Out:
#          cijena kvadratura                                             naslov  \
# 0  1.107.951 kn      77 m2  SREDNJACI, PROSTRAN 3-SOBAN STAN NA ODLIČNOJ L...
# 1    517.044 kn      35 m2                                  Maksimir - Remete
# 2  1.477.268 kn     106 m2                                     Remete 4 sobni
# 3    738.634 kn      56 m2       NA PRODAJU 2S STAN,56m2,I-KAT,ZAGREB,KNEŽIJA
# 4    674.690 kn      55 m2  DUBRAVA, MIROŠEVEČKA C: STAN U NOVOGRADNJI, 55 m2
# 5    544.373 kn      36 m2          Zagreb, Kvatrić, 1-sobni 36,85 m2 PRILIKA
# 6    849.429 kn      54 m2  Trešnjevka, Ozaljska, 2.s.stan, 54m2 na 1.katu...
# 7  1.809.654 kn     135 m2                       Zagreb, Ksaver, stan, 135 m2
# 8    701.702 kn      76 m2     Zagreb, Sesvete, 3-sobni stan s terasom, 76 m2
# 9  1.137.496 kn      98 m2  Zagreb-Gajnice, 3.5-sobni stan u zgradi, proda...
#
#   sobnost
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# ...

# %%
data.describe()
# Out:
#             cijena kvadratura  \
# count          380        380
# unique          18         17
# top     465.339 kn      77 m2
# freq            40         40
#
#                                                    naslov  \
# count                                                 399
# unique                                                 18
# top     Centar, blizina Kvaternikovog trga, lijep 1sob...
# freq                                                   42
#
#                                               sobnost
# count                                             152
# unique                                             28
# top     <span class="classified-param-value">1</span>
# freq                                               18

# %%
data.isnull().sum()
# Out:
# cijena         19
# kvadratura     19
# naslov          0
# sobnost       247
# dtype: int64

# %%
del data['sobnost']

# %%
data.head(10)
# Out:
#          cijena kvadratura                                             naslov
# 0  1.107.951 kn      77 m2  SREDNJACI, PROSTRAN 3-SOBAN STAN NA ODLIČNOJ L...
# 1    517.044 kn      35 m2                                  Maksimir - Remete
# 2  1.477.268 kn     106 m2                                     Remete 4 sobni
# 3    738.634 kn      56 m2       NA PRODAJU 2S STAN,56m2,I-KAT,ZAGREB,KNEŽIJA
# 4    674.690 kn      55 m2  DUBRAVA, MIROŠEVEČKA C: STAN U NOVOGRADNJI, 55 m2
# 5    544.373 kn      36 m2          Zagreb, Kvatrić, 1-sobni 36,85 m2 PRILIKA
# 6    849.429 kn      54 m2  Trešnjevka, Ozaljska, 2.s.stan, 54m2 na 1.katu...
# 7  1.809.654 kn     135 m2                       Zagreb, Ksaver, stan, 135 m2
# 8    701.702 kn      76 m2     Zagreb, Sesvete, 3-sobni stan s terasom, 76 m2
# 9  1.137.496 kn      98 m2  Zagreb-Gajnice, 3.5-sobni stan u zgradi, proda...

# %%
data['kvadratura'] = data['kvadratura'].str.replace(r'\D', '')

# %%
data['cijena'] = data['cijena'].str.replace(r'\D', '')

# %%
data
# Out:
#       cijena kvadratura                                             naslov
# 0    1107951        772  SREDNJACI, PROSTRAN 3-SOBAN STAN NA ODLIČNOJ L...
# 1     517044        352                                  Maksimir - Remete
# 2    1477268       1062                                     Remete 4 sobni
# 3     738634        562       NA PRODAJU 2S STAN,56m2,I-KAT,ZAGREB,KNEŽIJA
# 4     674690        552  DUBRAVA, MIROŠEVEČKA C: STAN U NOVOGRADNJI, 55 m2
# 5     544373        362          Zagreb, Kvatrić, 1-sobni 36,85 m2 PRILIKA
# 6     849429        542  Trešnjevka, Ozaljska, 2.s.stan, 54m2 na 1.katu...
# 7    1809654       1352                       Zagreb, Ksaver, stan, 135 m2
# 8     701702        762     Zagreb, Sesvete, 3-sobni stan s terasom, 76 m2
# 9    1137496        982  Zagreb-Gajnice, 3.5-sobni stan u zgradi, proda...
# 10    435794        452  Uređeni podrumski stan na Medveščaku u blizini...
# ...

# %%
data=data.dropna()
data
# Out:
#       cijena kvadratura                                             naslov
# 0    1107951        772  SREDNJACI, PROSTRAN 3-SOBAN STAN NA ODLIČNOJ L...
# 1     517044        352                                  Maksimir - Remete
# 2    1477268       1062                                     Remete 4 sobni
# 3     738634        562       NA PRODAJU 2S STAN,56m2,I-KAT,ZAGREB,KNEŽIJA
# 4     674690        552  DUBRAVA, MIROŠEVEČKA C: STAN U NOVOGRADNJI, 55 m2
# 5     544373        362          Zagreb, Kvatrić, 1-sobni 36,85 m2 PRILIKA
# 6     849429        542  Trešnjevka, Ozaljska, 2.s.stan, 54m2 na 1.katu...
# 7    1809654       1352                       Zagreb, Ksaver, stan, 135 m2
# 8     701702        762     Zagreb, Sesvete, 3-sobni stan s terasom, 76 m2
# 9    1137496        982  Zagreb-Gajnice, 3.5-sobni stan u zgradi, proda...
# 10    435794        452  Uređeni podrumski stan na Medveščaku u blizini...
# ...

# %%
#nemoj ga runat!!!!obrisat ce jos jedan red
data['kvadratura'] = data.apply(lambda x: x['kvadratura'][:-1], axis = 1)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data
# Out:
#       cijena kvadratura                                             naslov
# 0    1107951         77  SREDNJACI, PROSTRAN 3-SOBAN STAN NA ODLIČNOJ L...
# 1     517044         35                                  Maksimir - Remete
# 2    1477268        106                                     Remete 4 sobni
# 3     738634         56       NA PRODAJU 2S STAN,56m2,I-KAT,ZAGREB,KNEŽIJA
# 4     674690         55  DUBRAVA, MIROŠEVEČKA C: STAN U NOVOGRADNJI, 55 m2
# 5     544373         36          Zagreb, Kvatrić, 1-sobni 36,85 m2 PRILIKA
# 6     849429         54  Trešnjevka, Ozaljska, 2.s.stan, 54m2 na 1.katu...
# 7    1809654        135                       Zagreb, Ksaver, stan, 135 m2
# 8     701702         76     Zagreb, Sesvete, 3-sobni stan s terasom, 76 m2
# 9    1137496         98  Zagreb-Gajnice, 3.5-sobni stan u zgradi, proda...
# 10    435794         45  Uređeni podrumski stan na Medveščaku u blizini...
# ...

# %%
#data['kvadratura'].int(1)

# %%
data
# Out:
#       cijena kvadratura                                             naslov
# 0    1107951         77  SREDNJACI, PROSTRAN 3-SOBAN STAN NA ODLIČNOJ L...
# 1     517044         35                                  Maksimir - Remete
# 2    1477268        106                                     Remete 4 sobni
# 3     738634         56       NA PRODAJU 2S STAN,56m2,I-KAT,ZAGREB,KNEŽIJA
# 4     674690         55  DUBRAVA, MIROŠEVEČKA C: STAN U NOVOGRADNJI, 55 m2
# 5     544373         36          Zagreb, Kvatrić, 1-sobni 36,85 m2 PRILIKA
# 6     849429         54  Trešnjevka, Ozaljska, 2.s.stan, 54m2 na 1.katu...
# 7    1809654        135                       Zagreb, Ksaver, stan, 135 m2
# 8     701702         76     Zagreb, Sesvete, 3-sobni stan s terasom, 76 m2
# 9    1137496         98  Zagreb-Gajnice, 3.5-sobni stan u zgradi, proda...
# 10    435794         45  Uređeni podrumski stan na Medveščaku u blizini...
# ...

# %%
#data['kvadratura'].floordiv(1)

# %%
#data['kvadratura'] = data['kvadratura'].astype(str).str[:-1].astype(np.int64)
# ostao je kvadrat m2 u kodu, s ovom funkcijom ga mičem,ne radiii

# %%
y = data.cijena

# %% [markdown]
# from sklearn.preprocessing import LabelEncoder
# labelencoder=LabelEncoder()
# for naslov in data.columns:
#     data[naslov] = labelencoder.fit_transform(data[naslov])

# %%
#from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
data['naslov'] = le.fit_transform(data.naslov.values)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
data
# Out:
#       cijena kvadratura  naslov
# 0    1107951         77       8
# 1     517044         35       3
# 2    1477268        106       7
# 3     738634         56       4
# 4     674690         55       1
# 5     544373         36      14
# 6     849429         54       9
# 7    1809654        135      13
# 8     701702         76      15
# 9    1137496         98      17
# 10    435794         45      10
# 11    405510         30      11
# 12   1100565         77       5
# 13    465339         21       0
# 14    465339         21       0
# 15    834656         57      16
# 16    627839         49       2
# 17   1551132        100       6
# 18    775566         52      12
# 38   1107951         77       8
# 39    517044         35       3
# 40   1477268        106       7
# 41    738634         56       4
# 42    674690         55       1
# 43    544373         36      14
# 44    849429         54       9
# 45   1809654        135      13
# 46    701702         76      15
# ...

# %%
#X = data['kvadratura','naslov']
data_features = ['kvadratura', 'naslov']

# %%
X = data[data_features]

# %%
X.describe()
# Out:
#            naslov
# count  380.000000
# mean     8.052632
# std      5.401785
# min      0.000000
# 25%      3.000000
# 50%      8.000000
# 75%     13.000000
# max     17.000000

# %%
X.head()
# Out:
#   kvadratura  naslov
# 0         77       8
# 1         35       3
# 2        106       7
# 3         56       4
# 4         55       1

# %%
#np.reshape(1, -1)

# %%
from sklearn.tree import DecisionTreeRegressor

# Define model. Specify a number for random_state to ensure same results each run
data_model = DecisionTreeRegressor(random_state=1)

# Fit model
data_model.fit(X, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=1, splitter='best')

# %%
print("Predviđanje za prvih 30 stanova:")
print(X.head(30))
print("Predviđanja su:")
print(data_model.predict(X.head(30)))
# Out:
# Predviđanje za prvih 30 stanova:
#    kvadratura  naslov
# 0          77       8
# 1          35       3
# 2         106       7
# 3          56       4
# 4          55       1
# 5          36      14
# 6          54       9
# 7         135      13
# 8          76      15
# 9          98      17
# 10         45      10
# 11         30      11
# 12         77       5
# 13         21       0
# 14         21       0
# 15         57      16
# 16         49       2
# 17        100       6
# 18         52      12
# 38         77       8
# 39         35       3
# 40        106       7
# 41         56       4
# 42         55       1
# 43         36      14
# 44         54       9
# 45        135      13
# 46         76      15
# 47         98      17
# 48         45      10
# Predviđanja su:
# [1107951.  517044. 1477268.  738634.  674690.  544373.  849429. 1809654.
#   701702. 1137496.  435794.  405510. 1100565.  465339.  465339.  834656.
# ...

# %%
#predikcija je približno točna
#na stranici stan od 135 kvadrata je 1 772 772 kn, model je predvidio stan od 135 kvadrata na cijenu od 1 809 654
# stan od 54 kvadrata je 553 237 kn, model je predvidio stan od 55  kvadrata 674690
# teško je predviditi točnu cijenu zbog lokacija stanova, dosta stanova ima lokaciju u strogom centru grada što znači utomatski dosta višu cijenu

# %% [markdown]
# #Kaggle - cross valiation
#
# import pandas as pd
# from sklearn.model_selection import train_test_split
#
# # Read the data
# train_data = data
# test_data = data
#
# # Remove rows with missing target, separate target from predictors
# train_data.dropna(axis=0, inplace=True)
# y = train_data
# train_data.drop(axis=1, inplace=True)
#
# # Select numeric columns only
# numeric_cols = [cname for cname in train_data.columns if train_data[cname].dtype in ['int64', 'float64']]
# X = train_data[numeric_cols].copy()
# X_test = test_data[numeric_cols].copy()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

my_pipeline = Pipeline(steps=[
    ('preprocessor', SimpleImputer()),
    ('model', RandomForestRegressor(n_estimators=50, random_state=0))
])

# %%
from sklearn.model_selection import cross_val_score

# Multiply by -1 since sklearn calculates *negative* MAE
scores = -1 * cross_val_score(my_pipeline, X, y,
                              cv=5,
                              scoring='neg_mean_absolute_error')

print("Average MAE score:", scores.mean())
# Out:
# Average MAE score: 0.0

# %%
#KAGGLE MINI COURSE

X_full = data
X_test_full = data

# %%
y = X_full.cijena
features = ['kvadratura', 'naslov']
X = X_full[features].copy()
X_test = X_test_full[features].copy()

# %%
X_full
# Out:
#       cijena kvadratura  naslov
# 0    1107951         77       8
# 1     517044         35       3
# 2    1477268        106       7
# 3     738634         56       4
# 4     674690         55       1
# 5     544373         36      14
# 6     849429         54       9
# 7    1809654        135      13
# 8     701702         76      15
# 9    1137496         98      17
# 10    435794         45      10
# 11    405510         30      11
# 12   1100565         77       5
# 13    465339         21       0
# 14    465339         21       0
# 15    834656         57      16
# 16    627839         49       2
# 17   1551132        100       6
# 18    775566         52      12
# 38   1107951         77       8
# 39    517044         35       3
# 40   1477268        106       7
# 41    738634         56       4
# 42    674690         55       1
# 43    544373         36      14
# 44    849429         54       9
# 45   1809654        135      13
# 46    701702         76      15
# ...

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=0)

# %%
X_train.head()
# Out:
#     kvadratura  naslov
# 8           76      15
# 209         77       8
# 323         77       8
# 256         98      17
# 349        135      13

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
print("Točnost:", lr.score(X_valid, y_valid)*100)
# Out:
# Točnost: 59.210526315789465

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# function for comparing different approaches
def score_dataset(X_train, X_valid, y_train, y_valid):
    model = RandomForestRegressor(n_estimators=100, random_state=0)
    model.fit(X_train, y_train)
    preds = model.predict(X_valid)
    return mean_absolute_error(y_valid, preds)

# %%
drop_X_train = X_train.select_dtypes(exclude=['object'])
drop_X_valid = X_valid.select_dtypes(exclude=['object'])

# %%
print("MAE from Approach 1 (Drop categorical variables):")
print(score_dataset(drop_X_train, drop_X_valid, y_train, y_valid))
# Out:
# MAE from Approach 1 (Drop categorical variables):
# 0.0

# %%
# All categorical columns
object_cols = [col for col in X_train.columns if X_train[col].dtype == "object"]

# Columns that can be safely label encoded
good_label_cols = [col for col in object_cols if 
                   set(X_train[col]) == set(X_valid[col])]
        
# Problematic columns that will be dropped from the dataset
bad_label_cols = list(set(object_cols)-set(good_label_cols))
        
print('Categorical columns that will be label encoded:', good_label_cols)
print('\nCategorical columns that will be dropped from the dataset:', bad_label_cols)
# Out:
# Categorical columns that will be label encoded: ['kvadratura']
#
# Categorical columns that will be dropped from the dataset: []

# %%
from sklearn.preprocessing import LabelEncoder
label_X_train = X_train.drop(bad_label_cols, axis=1)
label_X_valid = X_valid.drop(bad_label_cols, axis=1)

# Apply label encoder
label_encoder = LabelEncoder()
for col in set(good_label_cols):
    label_X_train[col] = label_encoder.fit_transform(X_train[col])
    label_X_valid[col] = label_encoder.transform(X_valid[col])

# %%
print("MAE from Approach 2 (Label Encoding):") 
print(score_dataset(label_X_train, label_X_valid, y_train, y_valid))
# Out:
# MAE from Approach 2 (Label Encoding):
# 0.0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Read the data
X_full = data
X_test_full = data

# Remove rows with missing target, separate target from predictors
X_full.dropna(axis=0, subset=['cijena'], inplace=True)
y = X_full.cijena
X_full.drop(['cijena'], axis=1, inplace=True)

# Break off validation set from training data
X_train_full, X_valid_full, y_train, y_valid = train_test_split(X_full, y, train_size=0.8, test_size=0.2, random_state=0)

# "Cardinality" means the number of unique values in a column
# Select categorical columns with relatively low cardinality (convenient but arbitrary)
categorical_cols = [cname for cname in X_train_full.columns if
                    X_train_full[cname].nunique() < 10 and 
                    X_train_full[cname].dtype == "object"]

# Select numerical columns
numerical_cols = [cname for cname in X_train_full.columns if 
                X_train_full[cname].dtype in ['int64', 'float64']]

# Keep selected columns only
my_cols = categorical_cols + numerical_cols
X_train = X_train_full[my_cols].copy()
X_valid = X_valid_full[my_cols].copy()
X_test = X_test_full[my_cols].copy()
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Anaconda\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
X_train.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [8, 209, 323, 256, 349]
